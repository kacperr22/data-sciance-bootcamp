# %% [markdown]
# <a href="https://colab.research.google.com/github/kacperr22/data-sciance-bootcamp/blob/main/02_pandas/app_store_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
pd.__version__
# Out:
# '1.5.3'

# %%
url = 'https://storage.googleapis.com/esmartdata-courses-files/ds-bootcamp/appstore_games.csv'
df_raw = pd.read_csv(url)
df_raw.head(5)
# Out:
#                                                  URL         ID  \
# 0   https://apps.apple.com/us/app/sudoku/id284921427  284921427
# 1  https://apps.apple.com/us/app/reversi/id284926400  284926400
# 2  https://apps.apple.com/us/app/morocco/id284946595  284946595
# 3  https://apps.apple.com/us/app/sudoku-free/id28...  285755462
# 4  https://apps.apple.com/us/app/senet-deluxe/id2...  285831220
#
#             Name Subtitle                                           Icon URL  \
# 0         Sudoku      NaN  https://is2-ssl.mzstatic.com/image/thumb/Purpl...
# 1        Reversi      NaN  https://is4-ssl.mzstatic.com/image/thumb/Purpl...
# 2        Morocco      NaN  https://is5-ssl.mzstatic.com/image/thumb/Purpl...
# 3  Sudoku (Free)      NaN  https://is3-ssl.mzstatic.com/image/thumb/Purpl...
# 4   Senet Deluxe      NaN  https://is1-ssl.mzstatic.com/image/thumb/Purpl...
#
#    Average User Rating  User Rating Count  Price In-app Purchases  \
# ...

# %%
df = df_raw.copy()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17007 entries, 0 to 17006
# Data columns (total 18 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   URL                           17007 non-null  object
#  1   ID                            17007 non-null  int64
#  2   Name                          17007 non-null  object
#  3   Subtitle                      5261 non-null   object
#  4   Icon URL                      17007 non-null  object
#  5   Average User Rating           7561 non-null   float64
#  6   User Rating Count             7561 non-null   float64
#  7   Price                         16983 non-null  float64
#  8   In-app Purchases              7683 non-null   object
#  9   Description                   17007 non-null  object
#  10  Developer                     17007 non-null  object
#  11  Age Rating                    17007 non-null  object
# ...

# %%
df.columns
# Out:
# Index(['URL', 'ID', 'Name', 'Subtitle', 'Icon URL', 'Average User Rating',
#        'User Rating Count', 'Price', 'In-app Purchases', 'Description',
#        'Developer', 'Age Rating', 'Languages', 'Size', 'Primary Genre',
#        'Genres', 'Original Release Date', 'Current Version Release Date'],
#       dtype='object')

# %%
df = df.drop(columns=['Subtitle', 'URL', 'Icon URL', 'Description', 'In-app Purchases', 'Primary Genre'])
df.head(5)
# Out:
#           ID           Name  Average User Rating  User Rating Count  Price  \
# 0  284921427         Sudoku                  4.0             3553.0   2.99
# 1  284926400        Reversi                  3.5              284.0   1.99
# 2  284946595        Morocco                  3.0             8376.0   0.00
# 3  285755462  Sudoku (Free)                  3.5           190394.0   0.00
# 4  285831220   Senet Deluxe                  3.5               28.0   2.99
#
#                   Developer Age Rating  \
# 0  Mighty Mighty Good Games         4+
# 1          Kiss The Machine         4+
# 2               Bayou Games         4+
# 3  Mighty Mighty Good Games         4+
# 4           RoGame Software         4+
#
#                                            Languages        Size  \
# 0  DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...  15853568.0
# 1                                                 EN  12328960.0
# 2                                                 EN    674816.0
# ...

# %%
df = df.set_index('ID')
df
# Out:
#                                  Name  Average User Rating  User Rating Count  \
# ID
# 284921427                      Sudoku                  4.0             3553.0
# 284926400                     Reversi                  3.5              284.0
# 284946595                     Morocco                  3.0             8376.0
# 285755462               Sudoku (Free)                  3.5           190394.0
# 285831220                Senet Deluxe                  3.5               28.0
# ...                               ...                  ...                ...
# 1474626442  Stack Puzzle : Rise Tower                  NaN                NaN
# 1474919257                  EachOther                  NaN                NaN
# 1474962324         Rabbit Vs Tortoise                  NaN                NaN
# 1474963671                     FaTaLL                  NaN                NaN
# 1475076711   The Three Kingdoms :Bomb                  NaN                NaN
#
# ...

# %%
df.describe()
# Out:
#        Average User Rating  User Rating Count         Price          Size
# count          7561.000000       7.561000e+03  16983.000000  1.700600e+04
# mean              4.060905       3.306531e+03      0.813419  1.157064e+08
# std               0.751428       4.232256e+04      7.835732  2.036477e+08
# min               1.000000       5.000000e+00      0.000000  5.132800e+04
# 25%               3.500000       1.200000e+01      0.000000  2.295014e+07
# 50%               4.500000       4.600000e+01      0.000000  5.676895e+07
# 75%               4.500000       3.090000e+02      0.000000  1.330271e+08
# max               5.000000       3.032734e+06    179.990000  4.005591e+09

# %%
df.describe().T
# Out:
#                        count          mean           std      min         25%  \
# Average User Rating   7561.0  4.060905e+00  7.514275e-01      1.0         3.5
# User Rating Count     7561.0  3.306531e+03  4.232256e+04      5.0        12.0
# Price                16983.0  8.134187e-01  7.835732e+00      0.0         0.0
# Size                 17006.0  1.157064e+08  2.036477e+08  51328.0  22950144.0
#
#                             50%          75%           max
# Average User Rating         4.5          4.5  5.000000e+00
# User Rating Count          46.0        309.0  3.032734e+06
# Price                       0.0          0.0  1.799900e+02
# Size                 56768954.0  133027072.0  4.005591e+09

# %%
df.describe(include=(object))
# Out:
#              Name                                   Developer Age Rating  \
# count       17007                                       17007      17007
# unique      16847                                        8693          4
# top     Additions  Tapps Tecnologia da Informa\xe7\xe3o Ltda.         4+
# freq            2                                         123      11806
#
#        Languages                   Genres Original Release Date  \
# count      16947                    17007                 17007
# unique       990                     1004                  3084
# top           EN  Games, Strategy, Puzzle             2/09/2016
# freq       12467                      778                    75
#
#        Current Version Release Date
# count                         17007
# unique                         2512
# top                       1/08/2019
# freq                            118

# %%
df.describe(include=(object)).T
# Out:
#                               count unique  \
# Name                          17007  16847
# Developer                     17007   8693
# Age Rating                    17007      4
# Languages                     16947    990
# Genres                        17007   1004
# Original Release Date         17007   3084
# Current Version Release Date  17007   2512
#
#                                                                      top  \
# Name                                                           Additions
# Developer                     Tapps Tecnologia da Informa\xe7\xe3o Ltda.
# Age Rating                                                            4+
# Languages                                                             EN
# Genres                                           Games, Strategy, Puzzle
# Original Release Date                                          2/09/2016
# Current Version Release Date                                   1/08/2019
#
# ...

# %%
df.describe(include=['object']).T
# Out:
#                               count unique  \
# Name                          17007  16847
# Developer                     17007   8693
# Age Rating                    17007      4
# Languages                     16947    990
# Genres                        17007   1004
# Original Release Date         17007   3084
# Current Version Release Date  17007   2512
#
#                                                                      top  \
# Name                                                           Additions
# Developer                     Tapps Tecnologia da Informa\xe7\xe3o Ltda.
# Age Rating                                                            4+
# Languages                                                             EN
# Genres                                           Games, Strategy, Puzzle
# Original Release Date                                          2/09/2016
# Current Version Release Date                                   1/08/2019
#
# ...

# %%
df.columns = [col.lower().replace(" ", '_')  for col in df.columns ]
df
# Out:
#                                  name  average_user_rating  user_rating_count  \
# ID
# 284921427                      Sudoku                  4.0             3553.0
# 284926400                     Reversi                  3.5              284.0
# 284946595                     Morocco                  3.0             8376.0
# 285755462               Sudoku (Free)                  3.5           190394.0
# 285831220                Senet Deluxe                  3.5               28.0
# ...                               ...                  ...                ...
# 1474626442  Stack Puzzle : Rise Tower                  NaN                NaN
# 1474919257                  EachOther                  NaN                NaN
# 1474962324         Rabbit Vs Tortoise                  NaN                NaN
# 1474963671                     FaTaLL                  NaN                NaN
# 1475076711   The Three Kingdoms :Bomb                  NaN                NaN
#
# ...

# %%
df.languages.value_counts()
# Out:
# EN                                                                            12467
# EN, ZH                                                                          354
# CS, NL, EN, FR, DE, IT, JA, KO, PL, PT, RU, ZH, ES, SV, ZH, TR                  277
# EN, ZH, ZH                                                                      248
# EN, DE                                                                          147
#                                                                               ...
# DA, NL, EN, FI, FR, DE, IT, JA, KO, NO, PL, PT, RU, ZH, ES, SV, ZH, TR, UK        1
# EN, FR, IT, JA, KO, PT, RU, ES, TR                                                1
# DA, NL, EN, FR, DE, IT, NB, PL, PT, ZH, ES, SV, ZH, TR                            1
# EN, PT, ZH                                                                        1
# AR, NL, EN, FR, DE, ID, IT, JA, KO, PT, RU, ZH, ES, SV, TH, ZH, TR, VI            1
# Name: languages, Length: 990, dtype: int64

# %%
df.languages.value_counts().nlargest()
# Out:
# EN                                                                12467
# EN, ZH                                                              354
# CS, NL, EN, FR, DE, IT, JA, KO, PL, PT, RU, ZH, ES, SV, ZH, TR      277
# EN, ZH, ZH                                                          248
# EN, DE                                                              147
# Name: languages, dtype: int64

# %%
df.age_rating.value_counts()
# Out:
# 4+     11806
# 9+      2481
# 12+     2055
# 17+      665
# Name: age_rating, dtype: int64

# %%
import seaborn as sbs
sbs.set()
df.age_rating.value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='age_rating'>

# %%
_ = df.age_rating.value_counts().plot(kind='bar')

# %%
df.price
# Out:
# ID
# 284921427     2.99
# 284926400     1.99
# 284946595     0.00
# 285755462     0.00
# 285831220     2.99
#               ...
# 1474626442    0.00
# 1474919257    0.00
# 1474962324    0.00
# 1474963671    0.00
# 1475076711    0.00
# Name: price, Length: 17007, dtype: float64

# %%
df.languages
# Out:
# ID
# 284921427     DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...
# 284926400                                                    EN
# 284946595                                                    EN
# 285755462     DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...
# 285831220     DA, NL, EN, FR, DE, EL, IT, JA, KO, NO, PT, RU...
#                                     ...
# 1474626442                                                   EN
# 1474919257                                                   EN
# 1474962324                                                   EN
# 1474963671                                                   EN
# 1475076711                                               EN, ZH
# Name: languages, Length: 17007, dtype: object

# %%
df.languages.str.split(', ').str.len()
# Out:
# ID
# 284921427     17.0
# 284926400      1.0
# 284946595      1.0
# 285755462     17.0
# 285831220     15.0
#               ...
# 1474626442     1.0
# 1474919257     1.0
# 1474962324     1.0
# 1474963671     1.0
# 1475076711     2.0
# Name: languages, Length: 17007, dtype: float64

# %%
df['number_languages'] = df.languages.str.split(', ').str.len()
df
# Out:
#                                  name  average_user_rating  user_rating_count  \
# ID
# 284921427                      Sudoku                  4.0             3553.0
# 284926400                     Reversi                  3.5              284.0
# 284946595                     Morocco                  3.0             8376.0
# 285755462               Sudoku (Free)                  3.5           190394.0
# 285831220                Senet Deluxe                  3.5               28.0
# ...                               ...                  ...                ...
# 1474626442  Stack Puzzle : Rise Tower                  NaN                NaN
# 1474919257                  EachOther                  NaN                NaN
# 1474962324         Rabbit Vs Tortoise                  NaN                NaN
# 1474963671                     FaTaLL                  NaN                NaN
# 1475076711   The Three Kingdoms :Bomb                  NaN                NaN
#
# ...

# %%
df.number_languages.value_counts()
# Out:
# 1.0      12566
# 2.0       1102
# 3.0        495
# 16.0       316
# 4.0        261
# 5.0        247
# 6.0        220
# 25.0       171
# 9.0        154
# 11.0       147
# 8.0        142
# 7.0        140
# 10.0       140
# 31.0       133
# 12.0        91
# 21.0        77
# 14.0        64
# 13.0        64
# 15.0        54
# 17.0        37
# 30.0        35
# 19.0        34
# 32.0        34
# 33.0        33
# 22.0        31
# 18.0        24
# 46.0        20
# 26.0        18
# 20.0        14
# 24.0        13
# 23.0        11
# 27.0        11
# 28.0         9
# 29.0         8
# 45.0         6
# 44.0         5
# 65.0         4
# 42.0         3
# 43.0         3
# 36.0         2
# 49.0         2
# 48.0         1
# 66.0         1
# 35.0         1
# 34.0         1
# 111.0        1
# 76.0         1
# Name: number_languages, dtype: int64

# %%
df.user_rating_count.value_counts()
# Out:
# 5.0        390
# 6.0        330
# 7.0        266
# 8.0        255
# 10.0       170
#           ...
# 6630.0       1
# 2144.0       1
# 2139.0       1
# 28454.0      1
# 1197.0       1
# Name: user_rating_count, Length: 1792, dtype: int64

# %%
df.user_rating_count.value_counts(dropna=False)
# Out:
# NaN        9446
# 5.0         390
# 6.0         330
# 7.0         266
# 8.0         255
#            ...
# 1292.0        1
# 1088.0        1
# 955.0         1
# 34376.0       1
# 1197.0        1
# Name: user_rating_count, Length: 1793, dtype: int64

# %%
df.isnull() ## cała macierz z pustymi wartosciami
# Out:
#              name  average_user_rating  user_rating_count  price  developer  \
# ID
# 284921427   False                False              False  False      False
# 284926400   False                False              False  False      False
# 284946595   False                False              False  False      False
# 285755462   False                False              False  False      False
# 285831220   False                False              False  False      False
# ...           ...                  ...                ...    ...        ...
# 1474626442  False                 True               True  False      False
# 1474919257  False                 True               True  False      False
# 1474962324  False                 True               True  False      False
# 1474963671  False                 True               True  False      False
# 1475076711  False                 True               True  False      False
#
# ...

# %%
df.isnull().sum() ## pokaze ile jest pustych wartosci w kazdej columnie
# Out:
# name                               0
# average_user_rating             9446
# user_rating_count               9446
# price                             24
# developer                          0
# age_rating                         0
# languages                         60
# size                               1
# genres                             0
# original_release_date              0
# current_version_release_date       0
# number_languages                  60
# dtype: int64

# %%
df.dropna()
# Out:
#                              name  average_user_rating  user_rating_count  \
# ID
# 284921427                  Sudoku                  4.0             3553.0
# 284926400                 Reversi                  3.5              284.0
# 284946595                 Morocco                  3.0             8376.0
# 285755462           Sudoku (Free)                  3.5           190394.0
# 285831220            Senet Deluxe                  3.5               28.0
# ...                           ...                  ...                ...
# 1473084135               Die Last                  3.0                6.0
# 1473181500            Basic Slosh                  5.0               30.0
# 1473559573     Idle Racing Tycoon                  5.0               51.0
# 1473680543     Glow Hockey Strike                  5.0                5.0
# 1474461379  Agadmator Chess Clock                  5.0               33.0
#
#             price                 developer age_rating  \
# ID
# ...

# %%
df.isnull().sum()
# Out:
# name                               0
# average_user_rating             9446
# user_rating_count               9446
# price                             24
# developer                          0
# age_rating                         0
# languages                         60
# size                               1
# genres                             0
# original_release_date              0
# current_version_release_date       0
# number_languages                  60
# dtype: int64

# %%
df = df.dropna()
df.isnull().sum()
# Out:
# name                            0
# average_user_rating             0
# user_rating_count               0
# price                           0
# developer                       0
# age_rating                      0
# languages                       0
# size                            0
# genres                          0
# original_release_date           0
# current_version_release_date    0
# number_languages                0
# dtype: int64
